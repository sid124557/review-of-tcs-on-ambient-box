# %%
#!/usr/bin/env python
# coding: utf-8
import nltk
import pandas as pd 
from nltk.corpus import stopwords
from nltk.cluster.util import cosine_distance
import numpy as np
import networkx as nx

# %%
 
def read_article(file_name):
    filedata=file_name
    article = filedata.split(". ")
    sentences = []

    for sentence in article:
        print(sentence)
        sentences.append(sentence.replace("[^a-zA-Z]", " ").split(" "))
    sentences.pop() 
    
    return sentences

# %%
def sentence_similarity(sent1, sent2, stopwords=None):
    if stopwords is None:
        stopwords = []
 
    sent1 = [w.lower() for w in sent1]
    sent2 = [w.lower() for w in sent2]
 
    all_words = list(set(sent1 + sent2))
 
    vector1 = [0] * len(all_words)
    vector2 = [0] * len(all_words)
 
    # build the vector for the first sentence
    for w in sent1:
        if w in stopwords:
            continue
        vector1[all_words.index(w)] += 1
 
    # build the vector for the second sentence
    for w in sent2:
        if w in stopwords:
            continue
        vector2[all_words.index(w)] += 1
 
    return 1 - cosine_distance(vector1, vector2)

# %%
def build_similarity_matrix(sentences, stop_words):
    # Create an empty similarity matrix
    similarity_matrix = np.zeros((len(sentences), len(sentences)))
 
    for idx1 in range(len(sentences)):
        for idx2 in range(len(sentences)):
            if idx1 == idx2: #ignore if both are same sentences
                continue 
            similarity_matrix[idx1][idx2] = sentence_similarity(sentences[idx1], sentences[idx2], stop_words)

    return similarity_matrix

# %%
data=pd.read_csv('tcs_rev.csv')

# %%
data
# Out:
#      Unnamed: 0                   date  \
# 0             0  posted on 05 Sep 2018
# 1             1  posted on 12 Aug 2020
# 2             2  posted on 26 Jul 2019
# 3             3  posted on 29 Aug 2020
# 4             4  posted on 21 Aug 2020
# ..          ...                    ...
# 155         155  posted on 27 Sep 2019
# 156         156  posted on 31 Jul 2020
# 157         157  posted on 30 Jul 2020
# 158         158  posted on 02 Aug 2020
# 159         159  posted on 25 Jul 2020
#
#                                           tital  \
# 0                   System Engineer  in Kolkata
# 1                        It Analyst  in Kolkata
# 2            Associate Consultant  in Bangalore
# 3    Assistant Consultant (ITIS)  in Whitefield
# 4            Assistant System Engineer  in Pune
# ..                                          ...
# 155               Process Associate  in Nagpur
# 156                    It Analyst  in Bangalore
# 157      Senior Process Associate  in Bengaluru
# 158                        Team Leader  in Pune
# 159         System Software Engineer  in Mumbai
#
#                                                  user  \
# 0                    Anonymous · Finance Division
# 1                        Anonymous · IoT Division
# 2                        Anonymous · EIS Division
# 3                       Anonymous · ITIS Division
# 4                Anonymous · It Services Division
# ..                                                ...
# 155               Anonymous · Logistics  Division
# 156                      Anonymous · BFS Division
# 157       Anonymous · Investment banking Division
# 158                  Anonymous · Finance Division
# 159   Anonymous · Information Technology Division
#
#                                                dislike  \
# 0    Dislikes 1. Growth: Not much scope of growth. ...
# 1    Dislikes Some of the managers are lagging with...
# 2    Dislikes 1. First of all, everybody in TCS are...
# 3     Dislikes Nothing to dislike about working at TCS
# 4    Dislikes Salary appraisal is very low for begi...
# ..                                                 ...
# 155  Dislikes There is no career growth.  I saw peo...
# 156  Dislikes Compensation, work culture , appraisa...
# 157                             Dislikes Work pressure
# 158                             Dislikes Work pressure
# 159  Dislikes Only one thing is salary hike otherwi...
#
#                                                   like  page_index
# 0    Likes Few things that are good: \r\n1. Job sec...           2
# 1    Likes I am carrying company provided laptop be...           2
# 2    Likes You can draw salary without doing any wo...           2
# 3    Likes Good and excellent job security provided...           2
# 4    Likes Apart from Job security the company prov...           2
# ..                                                 ...         ...
# 155  Likes I was so excited to work for TCS.  But m...          17
# 156  Likes not supporting at all. Have been applyin...          17
# 157  Likes Job security is good and work culture an...          17
# 158  Likes Job security is the best part of TCS, ev...          17
# 159  Likes Best company to work with.\r\nWorking wi...          17
#
# [160 rows x 7 columns]

# %%
nltk.download("stopwords")
stop_words = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/siddharth/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def generate_summary(file_name, top_n=5):
    
    summarize_text = []

    # Step 1 - Read text anc split it
    sentences =  read_article(file_name)

    # Step 2 - Generate Similary Martix across sentences
    sentence_similarity_martix = build_similarity_matrix(sentences, stop_words)

    # Step 3 - Rank sentences in similarity martix
    sentence_similarity_graph = nx.from_numpy_array(sentence_similarity_martix)
    try:
        scores = nx.pagerank(sentence_similarity_graph)
    except Exception as e:
        print(e)
        return("NaN")

    # Step 4 - Sort the rank and pick top sentences
    ranked_sentence = sorted(((scores[i],s) for i,s in enumerate(sentences)), reverse=True)    
    #print("Indexes of top ranked_sentence order are ", ranked_sentence)    
    for i in range(top_n):
        try:
            #print("top_n---->",top_n)
            #print("ranked_sentence----->",ranked_sentence)
            summarize_text.append(" ".join(ranked_sentence[i][1]))
        except Exception as e:
            print(e)
            pass

    # Step 5 - Offcourse, output the summarize texr
    print("Summarize Text: \n", ". ".join(summarize_text))

# let's begin
for i in data.like:
    generate_summary( i, 2)
# Out:
# Likes Few things that are good:
# 1
# Job security
# In my opinion 80% of the  people who are in TCS is because of job security
# TCS holds onto their employees even in tough situations in market although there was a large layoff in recent past
# Still job security is a plus.
# 2.Work-life balance:  It is good
# Most of the time there are no pressure and also work is not much challenging
# So usually after the timid learning curve it is   easy work-wise
# In support projects timing may be an issue because one may have to support weekend or at night but those are compensated
# In development projects timing at beginning is casual but at time of delivery it is haywire because always there are no time but lot of development left
# This should give an idea of poor management.
# 3
# Benefits: Nice health benefits for employee and family, easy on leaves about maternity, wedding etc
# ...Read More
# Summarize Text:
#  In my opinion 80% of the  people who are in TCS is because of job security. Still job security is a plus.
# 2.Work-life balance:  It is good
# Likes I am carrying company provided laptop before this pandemic hits in
# As a DevOps Engineer, I already have VPN and admin privileges turned on long before
# I have not faced any lag during WFH period
# Company is also providing Internet connection charges
# I am quite happy what TCS is doing
#
# Summarize Text:
#  Likes I am carrying company provided laptop before this pandemic hits in. Company is also providing Internet connection charges
# Likes You can draw salary without doing any work and even without going to office a single day in a month.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Good and excellent job security provided by TCS during this pandemic
# Good company policies and excellent support for the employes by providing work from home option.
# list index out of range
# Summarize Text:
#  Likes Good and excellent job security provided by TCS during this pandemic
# Likes Apart from Job security the company provides various opportunities for skill development
# The flexible working environment and various benefits provided by the company are other plus points.
# list index out of range
# Summarize Text:
#  Likes Apart from Job security the company provides various opportunities for skill development
# Likes TCS had started the precautionary measures since the early stages of covid and most of the employees were stationed to work from home as new normal
#
# The company has been instrumental in keeping the psychological parameters balanced in this tough time with the help of different programs and expert views
# Work life balance is equally taken care of
#
# Summarize Text:
#  Work life balance is equally taken care of. Likes TCS had started the precautionary measures since the early stages of covid and most of the employees were stationed to work from home as new normal
# Likes Job security is only better compared to other companies but lot of internal politics.
# Employees suffer a lot because of role change or project change.
#
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS support is extraordinary during this pandemic by giving work from home option
# There is no risk of covid to the associates and also no impact in productivity
# But the thing is working hours has become more than 9hrs and still hikes are not there.
# Summarize Text:
#  There is no risk of covid to the associates and also no impact in productivity. Likes TCS support is extraordinary during this pandemic by giving work from home option
# Likes Life at TCS is all dependant on the type of Project one is allocated to but still one can find these things good.
# 1
# Job Security is best.
# 2
# A good work-life balance (at few times things may become hectic but at other times it's balanced).
# 3
# Too many people to interact with.
# 4
# Chance to work on the very latest technologies (again it's project specific).
# 5
# Onsite possibility which is decided as per the following(just some unanimous conclusion),
# a) The project has On-site work.
# b) Years of working at TCS by the employee.
# c) Immeasurable Knowledge with equally impressive articulation skill with good soft skills (Soft-skill is very important).
# d) Very good at fooling people and convincing them for one's good.
# 6
# Work-environment depends on the type of  associates one works with(mine was good)....Read More
# Summarize Text:
#  Onsite possibility which is decided as per the following(just some unanimous conclusion),
# a) The project has On-site work.
# b) Years of working at TCS by the employee.
# c) Immeasurable Knowledge with equally impressive articulation skill with good soft skills (Soft-skill is very important).
# d) Very good at fooling people and convincing them for one's good.
# 6. Likes Life at TCS is all dependant on the type of Project one is allocated to but still one can find these things good.
# 1
# Likes TCS the name says it all
# When it's Tata it's always BEST
# Best and most secure company one can imagine at this crisis and pandemic time
#  Job security, complete and comfortable work from home, good work life balance.
# A
# Very employee friendly company
#
# (PowerIterationFailedConvergence(...), 'power iteration failed to converge within 100 iterations')
# Likes Security
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security is the only thing I would like to appreciate during this COVID 19 lockdown
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TATA is the only company that comes up heartfully to help not only its associates and also their near family members
# I am very proud to say I am an employee of TATA.
# list index out of range
# Summarize Text:
#  Likes TATA is the only company that comes up heartfully to help not only its associates and also their near family members
# Likes Work life balance
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security for people who are already earning good can switch to the company but freshers do not expect for good growth here
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes You will see job security mentioned in all the posts, TCS has a good brand name and you can flaunt it and it is a matter of pride
# The learning opportunities are immense as the learning and development has plethora of articles, exams and training material to enhance your skills
# The compensation is the best among the MNC;s but depends on your managers perspective
# Sycophancy is omnipresent, needless to say, having said that I will still mention salary part the positives  The medical and the digital claim system makes the life easy, the facilities like gym and cafeteria varies from location to location, if you are lucky enough to be deputed at a good place you will get good amenities, place like Malad is an old asylum
# The infrastructure is poor
# Cons of getting stuck in an internal project
# ...Read More
# Summarize Text:
#  Sycophancy is omnipresent, needless to say, having said that I will still mention salary part the positives  The medical and the digital claim system makes the life easy, the facilities like gym and cafeteria varies from location to location, if you are lucky enough to be deputed at a good place you will get good amenities, place like Malad is an old asylum. Likes You will see job security mentioned in all the posts, TCS has a good brand name and you can flaunt it and it is a matter of pride
# Likes Is not for who looking for challenging and skill development roles, but good for easy go minded people and job secure people.
# Not at all good for youngsters
# list index out of range
# Summarize Text:
#  Likes Is not for who looking for challenging and skill development roles, but good for easy go minded people and job secure people.
# Likes Very less salaries in this company as compare to market,and they are not given any bonus for the covid 19 situation rather than increment of salary,we are doing our work from home too.but company not provided increment .There is not decreased the work even covid 19 situations
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Good environment
# Due to COVID 19 lockdown work from home is provided, hence it's very safe for employees.
# list index out of range
# Summarize Text:
#  Likes Good environment
# Likes Onsite opportunities
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS is not supporting us during the lockdown
# They are asking employees to come back from home and stay near the office in spite of the dangerous on-going condition.
# They have neither provided laptops nor provided internet for working from home in spite of the fact that the company has thousands of crores of profit every quarter.
# Also one should never join TCS in their career starting days, as they will destroy your life completely, No learning
# I am AGAIN REPEATING you WILL NOT learn anything in this company....Read More
# Summarize Text:
#  They are asking employees to come back from home and stay near the office in spite of the dangerous on-going condition.
# They have neither provided laptops nor provided internet for working from home in spite of the fact that the company has thousands of crores of profit every quarter.
# Also one should never join TCS in their career starting days, as they will destroy your life completely, No learning. Likes TCS is not supporting us during the lockdown
# Likes Overall experience is good
# But a lot of people keep wasting their and company's time here
# This indirectly impact the hard working bunch
# TCS has been supportive during this COVID period
# It's been a continuous WFH since April and company keep gathering information on associate's well being
# There are covid corner, dedicated helpline number and on call docto's assistance to help someone out.
# Summarize Text:
#  It's been a continuous WFH since April and company keep gathering information on associate's well being. But a lot of people keep wasting their and company's time here
# Likes TCS one of tha multinational com
# Is very soft and nice place to working to everyone desire and evry person dreams come true and  TCS is tha most comfortable working Environment compare to other compny.
# list index out of range
# Summarize Text:
#  Likes TCS one of tha multinational com
# Likes The company support is very good
# Special thanks to Ratan Tata sir for donating huge amount to need one’s.
# list index out of range
# Summarize Text:
#  Likes The company support is very good
# Likes Really hands up to this organization because as in this situation many peoples are unable to working and company is not let them.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes its best..
# in terms of security,work life balance,team , other activities and skill development
# list index out of range
# Summarize Text:
#  Likes its best..
# Likes Good work environment and culture
# There is a huge cafeteria and gaming arcade for chilling
# Company policies are good
# Appraisal are fair and they give salary hike and bonus nothing
#
# Summarize Text:
#  Likes Good work environment and culture. Company policies are good
# Likes In this situation company supporting us very well
# There is issue with salary as there is no deduction
#
# Summarize Text:
#  There is issue with salary as there is no deduction. Likes In this situation company supporting us very well
# Likes It's like govt job,work culture excellent, excellent company policies, unbelievable about TCS policies.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I can consider it as one of the most reliable organisations during this global pandemic,
# Thought there are lots of internal projects are suffering, still there allocating project to their associates, I have friends in other MNCs, they are simply asking them to stay on the bench or indirectly forcing me to leave the job,
#
# But as per my personal realisation,END OF THE DAY WHAT WILL SAVE YOU IS YOUR PRODUCTIVITY...Read More
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Work life balance is there
# No frequent weekend workings.job security is there
# No politics
# Teammates are from different cultural background and work happily with each other
# Salary n other compnsations are good
# Mediclaim policies n insurance are excellent.
# Summarize Text:
#  Teammates are from different cultural background and work happily with each other. Likes Work life balance is there
# Likes TCS has handled the pandemic situation in very great manner
# They implemented work from home culture immediately due to the wide spread of Corona virus taking associates health as a primary concern
# The same has been communicated to the clients
#
# Summarize Text:
#  They implemented work from home culture immediately due to the wide spread of Corona virus taking associates health as a primary concern. The same has been communicated to the clients
# Likes Tcs is supporting Work from home
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes In this pandemic there is secure job which means a lot.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes As i was a Contractor employee from last 5 years they treated like me a contractor and removed me within 15 days during this COVID-19 pandemic..Now how can I trust and what will I like about this company who cannot support their contractor employees during this situation also...very bad experience
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes When you think about tcs yes they are given job security..but then after their is not personal life..it was like burden for us..there is no growth in financially..
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Learning opportunities.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Work culture is good, as colleagues used to support a lot, together as team we used to work hard & enjoy as well, work life balance used to be good, overall experience is great.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes In lockdown time TCS pay the salary to all employees and also provide the COVID health centers this is very usefull for all TCS employees.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes The Working Culture
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I don't like any thing in tcs
# Manager always support local guys
# No support during covid time
# My manager didn't inform me about tcs system is required and after the they are calling us to base location.
# Summarize Text:
#  No support during covid time. Manager always support local guys
# Likes TCS is Awesome company to work in IT industry, you get all the support from the mgmt team and freedom to work.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I mostly like their health insurance policy
# You will get the treatment from best hospital in the country under the mediclaim
# No need to worry for the hospital bill
#
# Summarize Text:
#  You will get the treatment from best hospital in the country under the mediclaim. No need to worry for the hospital bill
# Likes Good support from TCS honestly
#   But timesheet policy has become very strict
#
# Summarize Text:
#  Likes Good support from TCS honestly.   But timesheet policy has become very strict
# Likes Job security
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I'm no longer an employee, I left the job in 2017 for higher studies
# HR Person and Managers helped alot for higher study policies
#
# Summarize Text:
#  Likes I'm no longer an employee, I left the job in 2017 for higher studies. HR Person and Managers helped alot for higher study policies
# Likes We can be 99% assured that our jobs are secured
# Also we have a lot of exposure and opportunities to improve ourself
# I feel proud and lucky working in TCS
# Summarize Text:
#  Likes We can be 99% assured that our jobs are secured. Also we have a lot of exposure and opportunities to improve ourself
# Likes Enjoyed my time working there
# Had good exposure on latest technologies (if you are part of Innovation labs) and flexible work timings :)
# list index out of range
# Summarize Text:
#  Likes Enjoyed my time working there
# Likes The most important thing is, TCS does not layoff anyone
# Though hiring for seniors are not happening, but those given offer, TCS is committed and did not cancelled the offer due to COVID
#
# It also helped in virtual joining in this pandemic situation
# It provided all employee to work from home.
# TCS is more project oriented and certain variables payments are based on projects
# But that is what consultant is expected to work on certain project.
# ...Read More
# Summarize Text:
#  Though hiring for seniors are not happening, but those given offer, TCS is committed and did not cancelled the offer due to COVID. Likes The most important thing is, TCS does not layoff anyone
# Likes Webinars for guidance for better heath in covid time, availability of heath experts, counsellors, daily tips, yoga sessions, ergonomic tips and sessions and a lot more.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Prakash Iyer Tower lead for telstra should be terminated immediately .
#
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes No layoffs, No deduction in salaries, COVID 19 cover, quarantine facility, oxygen cylinder facility for employee and dependent and lot more.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Really supportive
# Work from home is comparatively safe during this period
# They have not called us back to office which is like risking our lives
# Hope TCS will let us work from home until corona is completely gone as there is life rosk everywhere
# We have a convenient work environment and we feel more productive for reasons like extended office hours
#
# Summarize Text:
#  We have a convenient work environment and we feel more productive for reasons like extended office hours. Hope TCS will let us work from home until corona is completely gone as there is life rosk everywhere
# Likes TCS has never let you feel that there is a recession going on
# I have no insecurities about my job nor about salary
# Everything have been maintained very smoothly and didn't even bother to let us know what is happening around the world.
# Summarize Text:
#  Likes TCS has never let you feel that there is a recession going on. I have no insecurities about my job nor about salary
# Likes We have full job security and on time salary payment but salary is too less and hike percentage is too low
# Plus because of covid we got zero hikes zero promotions this year
# Its too hard to grep financially in this company
# If you looking for making good money as yur ground rule, then this is not the company for you
#
# Summarize Text:
#  Its too hard to grep financially in this company. If you looking for making good money as yur ground rule, then this is not the company for you
# Likes No company culture full of micro management worst managers No promotion or hikes
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I havent come across any incident of lay off
# The employees continue to get their regular compensation
# TATA has been kind  and compassionate
# I believe the projects have been a little over the edge by bumping up the pressure at this hour of pandemic
# Summarize Text:
#  The employees continue to get their regular compensation. TATA has been kind  and compassionate
# Likes I was one of the employees of TCS, now I am not part of the company, but when I worked with TCS it was all time I felt better and I felt I am at a safe place, given a opportunity I want to continue my services with TCS
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes In this pandemic it has never stopped the salary
# Also have provided camp for the covid affected employees
# list index out of range
# Summarize Text:
#  Likes In this pandemic it has never stopped the salary
# Likes Good health policies
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes There has been no increment this year
# But in these uncertain circumstances, TCS has promised no job cuts
# And it has also provided reimbursement facilities for some work from home paraphernalias
# HR's have called a number of associates enquiring about overall health of the associate and family
# It has also provided helpline numbersfor various issues that might arise if an associate Or a family member is COVID infected
# Overall, TCS has handled the situation fairly well.Of course, lack of any increments this year has demotivated a number of associates but as of now, I choose to overlook that
# ...Read More
# Summarize Text:
#  Overall, TCS has handled the situation fairly well.Of course, lack of any increments this year has demotivated a number of associates but as of now, I choose to overlook that. It has also provided helpline numbersfor various issues that might arise if an associate Or a family member is COVID infected
# Likes job security,work life balance
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Recognition of hard worker
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Good work environment and cultures
# Leave policies and HR team always supportive
# list index out of range
# Summarize Text:
#  Likes Good work environment and cultures
# Likes Except compensation everything is good.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I want work in TCS,i have 4.5 year experience in accounts department.Good work environment in tcs.if I will work in TCs so my dream will be completed
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Good opportunities for learning new technologies and for travelling abroad.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes WAS HAPPY DURING THE OPENING YEAR OF JOB
# BECOME WORKING LIKE A MACHINE IN THE LATER YEARS
# LOST JOB SATISFACTION
# LATER I LEFT THE JOB.
# Summarize Text:
#  Likes WAS HAPPY DURING THE OPENING YEAR OF JOB. LOST JOB SATISFACTION
# Likes TCS taking care all majors
#  Very caring organisation
#  Good Job
# Summarize Text:
#  Likes TCS taking care all majors.  Very caring organisation
# Likes Job security is poor, work culture and management is okay , company policies are poor
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Love TCS
# Really missing everything
# Lot of new things
# Every day is new learning in TCS, been into different projects , get to see/meet/talk with different people
#
# Lot of learning
# Ample amount of opportunities.
# Summarize Text:
#  Every day is new learning in TCS, been into different projects , get to see/meet/talk with different people.
# Lot of learning
# Likes There is no support at all from the management in the project that I am working in
# Instead there is extra pressure put on the team to not take leaves because this would make them earn more revenue
# There has been no calls with me till now when I have been asked about how I am holding up in this situation
# Obviously the good thing is Tcs perhaps won't fire us in these tough times but nothing other than that
# No hike and otherwise very bad company culture to work in....Read More
# Summarize Text:
#  There has been no calls with me till now when I have been asked about how I am holding up in this situation. Obviously the good thing is Tcs perhaps won't fire us in these tough times but nothing other than that
# Likes Tcs is covering covid 19 in health issurance
# And also providing self quarantine rooms who needs them
# While other companies are firing employees ,Tcs is ensuring job security
# Summarize Text:
#  Likes Tcs is covering covid 19 in health issurance. And also providing self quarantine rooms who needs them
# Likes Flowrish teammates, sharp time training, job security depends on facility faculty, want to increase my lifestyle adding term growth appraisal, travel we don't have 4wheelers but some time 2 wheelers help to continue to review our lifestyle,like to give suggesyion only for politics having good learning skill or we make our friendly environment, I am going to find my own wife in-innovation
# My working lifestyles is quite different from others here I want to make my own environment or can say balanced working life
# ...Read More
# list index out of range
# Summarize Text:
#  Likes Flowrish teammates, sharp time training, job security depends on facility faculty, want to increase my lifestyle adding term growth appraisal, travel we don't have 4wheelers but some time 2 wheelers help to continue to review our lifestyle,like to give suggesyion only for politics having good learning skill or we make our friendly environment, I am going to find my own wife in-innovation
# My working lifestyles is quite different from others here I want to make my own environment or can say balanced working life
# Likes I worked in world's safest organization, at whatever condition will be my job is secure
# Also every higher management people pay attention towards your health
# If u are effected with virus
# Summarize Text:
#  Likes I worked in world's safest organization, at whatever condition will be my job is secure. Also every higher management people pay attention towards your health
# Likes They are providing work from home
# Offices are closed for covid-19 situation
# And they are also providing some facilities for covid-19 such as some healthcare facilities, meeting communication expense facilities due to covid despite current situation of companies economic conditions
# Although sometimes going got tough but still I'm in the company for 9 years now and they have not removed me yet.
# Summarize Text:
#  And they are also providing some facilities for covid-19 such as some healthcare facilities, meeting communication expense facilities due to covid despite current situation of companies economic conditions. Offices are closed for covid-19 situation
# Likes I have a lot of respect for TCS in my heart, though i wish to leave the organisation for future growth but I really respect TATA GROUP it's the best thing India can have
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Although no hike for the FY, however job was secured.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I am glad I got the opportunity to work with TCS
# Here they maintain a good work environment for all the employees and provide various opportunities to learn new skills.
# list index out of range
# Summarize Text:
#  Likes I am glad I got the opportunity to work with TCS
# Likes If you want Job security and work life balance and family culture then TCS is the best company to work with
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Providing 85% employess WFH
# For rest of the employees the are adding extra allowance whi are requested to Work From Office
# list index out of range
# Summarize Text:
#  Likes Providing 85% employess WFH
# Likes I liked the Job security
# Overall TCS is good in supporting Covid situation
# list index out of range
# Summarize Text:
#  Likes I liked the Job security
# Likes In every way and as always work life balance is ensured.Exclusively team is made to work in closed loop with higher management.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I had a friendly team at TCS and work culture was so good
#
# list index out of range
# Summarize Text:
#  Likes I had a friendly team at TCS and work culture was so good
# Likes The support I have received during COVID-19 pandemic resulted in worldwide lockdown was encouraging but not sure how things would shape in coming months.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Tcs was not cutting any payment to any employees also they  r give leave how much employee want it is a no one company  in all world  .I fill proud to be a part of tcs
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS is very supportive in career development area but while paying the money to the employee is I will say worst.
# I have left the company in January 2020 but still waiting for my FFS.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Great work culture in this pendamic , we all are giving our 100%
# Thank u so much to The great Mr Ratan tata
# We need more people in our world  like Ratan tata sir.
# Summarize Text:
#  Thank u so much to The great Mr Ratan tata. Likes Great work culture in this pendamic , we all are giving our 100%
# Likes Being proud to be a Tcs'r..
# Safety and comfortable zone to work with....
#
# Summarize Text:
#  Safety and comfortable zone to work with..... Likes Being proud to be a Tcs'r..
# Likes working with TCS is long lasting experience, such a good company providing many opportunities
# Take care of employees first, known for ethics and values.
# list index out of range
# Summarize Text:
#  Likes working with TCS is long lasting experience, such a good company providing many opportunities
# Likes TCS is best among all the service based organizations in India
# In this pandemic scenario where every other company is laying off people, I didn't hear a single person has to leave TCS
# They are even providing certain amount of medical expenses for Covid treatment also
# They are not businessman, they are industrialists and they prove it all the time
# TCS is a 5 star organization.
# Summarize Text:
#  Likes TCS is best among all the service based organizations in India. In this pandemic scenario where every other company is laying off people, I didn't hear a single person has to leave TCS
# Likes Very good job security
# But from learning perspective there ar some gaps, bt this happens in want domain and project you are working upon
# Overall it was good and my 1st organisation
# I feel proud.
# Summarize Text:
#  Overall it was good and my 1st organisation. Likes Very good job security
# Likes Good work environment and culture
# Teammates are supportive and the management is transplant
# They is a huge cafeteria gaming arcade for chilling
# Company policies are good, and they give salary hike
#
# Summarize Text:
#  They is a huge cafeteria gaming arcade for chilling. Teammates are supportive and the management is transplant
# Likes 1
# Job security.
# 2
# More learning growth like other than your project that have conducted so many training sessions.
# 3
# Proper dress coding same has been checked by security regularly.
# 4
# In this COVID situation, proper asset management team, still they are planning different ways to finding the x to y employees should have assets in WFH location.
# Summarize Text:
#  Proper dress coding same has been checked by security regularly.
# 4. More learning growth like other than your project that have conducted so many training sessions.
# 3
# Likes Totally worst don't join the Hyderabad office tcs
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes 3 months of training for Freshers graduate is very good
# Everyone will get good learning opportunity during that period and most important thing is you will be connected with people from different location with diverse culture which is very important for everyone to cope up with the corporate environment after completion of school and college life
# In projects you will have colleagues of different age groups, so you will not feel bore
# Very few employee stays in bench in current scenario
# Different projects are available but mostly are support and maintenance project
# You will get opportunity to learn new things
# TCS is good for CAB and Bus service in Kolkata location
# Girls get CAB from 8 PM and boys get from 10 PM
# Not sure about other locations in Kolkata we had Bus service in free of cost for pick up and drop
# TCS is well known for CSR activity as well
# TCS Maitree club organizes different extra curricular activity stating from painting, dancing, trekking and adventure activity
# And in the end TCS is famous for MEDICLAIM service I must say
# I am not sure about other companies but you don't need to bother about money when you or your family member is sick if they are insured under their scheme...Read More
# Summarize Text:
#  TCS is good for CAB and Bus service in Kolkata location. Everyone will get good learning opportunity during that period and most important thing is you will be connected with people from different location with diverse culture which is very important for everyone to cope up with the corporate environment after completion of school and college life
# Likes Tcs was such a good place with full of opportunities in different fields..but currently I'm not working I left TCS inn2018 due to higher studies
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes It has been handled very well  ie work from home .i feel so proud that how it (wfh)has been carried out for each employees
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Good environment and supportive people
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes No layoff, no salary cut until some grades, good opportunities inside organization but it's pure luck.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Safe job
#
# Wfh
# Good thing is -Medical facilities and secured job
# list index out of range
# Summarize Text:
#  Likes Safe job
# Likes They have truly stood by each and everyone of its associates and treated us with utmost dignity in this difficult time
# I will always be grateful to them.
# list index out of range
# Summarize Text:
#  Likes They have truly stood by each and everyone of its associates and treated us with utmost dignity in this difficult time
# Likes I like work culture, work life balance and support during pandemic is excellent
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS HR department is in touch monthly and I got WFH facility for work.
# Overall is good.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes They are not supporting
# They have lack of resources and the management at every level is just worried about customer no matter what happen with employee
# Everyone is struggling for laptop and they asking to get desktop from
# Baselocatiin
# Summarize Text:
#  They have lack of resources and the management at every level is just worried about customer no matter what happen with employee. Likes They are not supporting
# Likes Company cares our employees during this covid 19 period by giving work from home
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Tata group is committed to values..
# you will have secured job even in this pandemic situation
#
# Summarize Text:
#  you will have secured job even in this pandemic situation. Likes Tata group is committed to values..
# Likes I am not working in TCS right now to answer this Question.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes It's an absolute pleasure working in this company
# They care for you like a family
# Almost every alternate months they call you to make sure that you as well as your family is doing fine
#
# Summarize Text:
#  They care for you like a family. Almost every alternate months they call you to make sure that you as well as your family is doing fine
# Likes Tcs company is also big brand of It and they are offering for work from home and during covid 19 they all are working it's a good thik they have
#
# list index out of range
# Summarize Text:
#  Likes Tcs company is also big brand of It and they are offering for work from home and during covid 19 they all are working it's a good thik they have
# Likes It's an amazing organization with full of talent's, happiness
# The work culture is so awesome
# I am happy to work and my trainers and Managers are very co-operative.
# Summarize Text:
#  The work culture is so awesome. Likes It's an amazing organization with full of talent's, happiness
# Likes By micro management
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Before Tcs I worked in three companies but seriously never ever felt experience like tcs
# I didn't only got salary from tcs, I've learnt a lot things in my office
# Seniors treat like parents they give us much opportunity to learn more and more
# I'm just Band 1 but I'll never ever leave this company because it helped me and also supported me in my  bad days
# I'll always serve in this company as my own company means I'll never treat myself just like a employee
# In past I took part in social work from office side and I'll always ready to do any type of social work given by my office
# I Love the environment of my office and behavior of my senior colleagues....Read More
# Summarize Text:
#  I'll always serve in this company as my own company means I'll never treat myself just like a employee. I'm just Band 1 but I'll never ever leave this company because it helped me and also supported me in my  bad days
# Likes My childhood dream is to join a good company
# But do not understand which company to go to, but oneday i had to talk about TCS company.Them my dream is that I should work in TCS company
# So that i can take my dream and company to the top
# At this time covid19 worried about the whole world, peoples  us are worried about it
# At this tim TCS company who have thought about the people for job selection  appreciated
# I thanks tcs company
# ...Read More
# Summarize Text:
#  But do not understand which company to go to, but oneday i had to talk about TCS company.Them my dream is that I should work in TCS company. I thanks tcs company
# Likes One of the best company to adopt new normal
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Supporting each employee with necessary support.
# They are delivering Computer to the home and also providing allowances for internet
#
# And happy to say that.
# TCS providing medical support for the employees that helping us alot..
# Summarize Text:
#  They are delivering Computer to the home and also providing allowances for internet. Likes Supporting each employee with necessary support.
# Likes The policies for the employees will always change and those are good one
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Friends circle is very good
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS Company support us in every situation, but some unexpected people make it worst for us and sometimes their behaviour stop us to reach our ambitions
# This is only the bad fact about organisation otherwise I love to stay with TCS , I like it's rule and none security for it's employees
# list index out of range
# Summarize Text:
#  Likes TCS Company support us in every situation, but some unexpected people make it worst for us and sometimes their behaviour stop us to reach our ambitions
# Likes Permanent job security but struggling to face HR when they call back to office during Covid19 cases increased drastically.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Never worked in this company, I don't know, I can only speak so much, I think by doing this work, I will get to learn a lot and I will give my best Duga company
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes TCS is removed all the BA's( Contract People) From the Organization.
# Please don't go for TCS ,The Job Security is Very Less for the BA;s People.
#
#
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes WHEN I TOOK A JOB IN TCS I'VE DECIDED NOT TO QUIT FROM THIS ORGANIZATION AND TAKING IT AS A ONE TIME CAREER OPPORTUNITY AND WORKED REALLY HARD TO FIND A BETTER POSITION OR ROLE IN MY FIRST TEAM AND AFTER ACHIEVING IT I GOT MOVED TO ONE ANOTHER TEAM WHERE THE CIRCUMSTANCES AREN'T REALLY ON MY SIDE DUE TO PROCESS MIGRATION I WAS MOVEDALONG WITH ALL MY TEAM MEMBERS BUT STILL GOT PLACED IN A GOOD TEAM RIGHT NOW AND I'M WORKING WITH THE GOOD PEOPLE SURROUNDED BY ME.
# THIS STORY COULD REVEAL THAT TCS IS A PLACE WHERE YOU CAN GET LEARNING, GET TO KNOW NEW WORLD OF CORPORATE BUSINESSES, CHALLENGING ENVIRONMENT TO IMPROVE OURSELVES, LAST RESORT FOR ALL THE EMPLOYEES PERSONAL FINANCIAL ASSISTANCE, A VERY GOOD PLATFORM FOR ALL THE DEEDS ANS NEEDS, RIGHT PLACE TO EXPLORE AND EVOLVE AROUND THE GLOBE AND MORE LIKELY A FAMILY..,...Read More
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Having 5years experience with TCS
# I am very proud to be an tcser.tcs have good policies and work environment.
# list index out of range
# Summarize Text:
#  Likes Having 5years experience with TCS
# Likes I have been working at Tata Consultancy Services since 3 years and 1 month and it has been a great experience working here!
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes This company help me in realising that our personal life also matters apart from professional life
# Got some great help from superiors in getting
# list index out of range
# Summarize Text:
#  Likes This company help me in realising that our personal life also matters apart from professional life
# Likes I like the culture and infrastructure at Tata Consultancy Service
# I am not getting any support from TCS since I was a C2H employee.
# list index out of range
# Summarize Text:
#  Likes I like the culture and infrastructure at Tata Consultancy Service
# Likes Worst
# The management force you to come to office
# They hide the covid positive cases in office in order to avoid panic and force you
# If you are in quarantine or not willing to come to office, they force you to apply leaves
# HR is useless.
# Summarize Text:
#  The management force you to come to office. If you are in quarantine or not willing to come to office, they force you to apply leaves
# Likes They gave antique computers for WFH.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Comapny is very helpful and kind to employees during this pandemic situation
# Job is well secured and I am happy to work as they have provided work from home strategy when this pandemic situation has started
# They have also provided me the working envt at home to support their business.
# Summarize Text:
#  Likes Comapny is very helpful and kind to employees during this pandemic situation. Job is well secured and I am happy to work as they have provided work from home strategy when this pandemic situation has started
# Likes It has been pleasure to be part of this firm from past 1 year
# During this tough time when other companies  are firing their employees, TCS has remain loyal to their staff
# Proud to be a TCSer
# Summarize Text:
#  Likes It has been pleasure to be part of this firm from past 1 year. During this tough time when other companies  are firing their employees, TCS has remain loyal to their staff
# Likes Feel good whenever they share awareness about present situation and taking care of us through texts by providing contact numbers.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Exceptionally high support during Covid.
#
# Job is secure,  salary is on time, management assurance that everyone is safe reduces anxiety.
#
# High level of communication and guidance
#
# Involvement in various activity, bringing celebrities chef, mountaineers, athletes.
#
# Ample support for psychological counseling.
#
# Good platformsfor collaboration
#
# Above all else, in any and all decisions,  employee safety is kept as priority, even at the cost of business.
#
# TCS should be rated as the top organisation, once it comes to support of employees during Covid ...Read More
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security and taking care of their employees.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security is the probability than  an individual will keep their job.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes In TCS, they is job secure, Month by month we can improve our knowledge using some still based training, and also as per process training they will conduct,..
# I can say they have good  infrastructure, They too help for needy people sharing they funds, mainly for covid they have following government rules etc..
# I can TCS good company..
#
# Summarize Text:
#  I can say they have good  infrastructure, They too help for needy people sharing they funds, mainly for covid they have following government rules etc... I can TCS good company..
# Likes Job security
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I am very happy to being a part of Tata Consultancy services
#
# list index out of range
# Summarize Text:
#  Likes I am very happy to being a part of Tata Consultancy services
# Likes I left job in covid because my team mentally harrased me and forced me to leave my job
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes As a TCSer, Yes, company has an ultimate support to me
# All the possible outcome to avoid spread of virus has been taken care of
# Work from home, safety precautions, updates, providing Mediclaim facilities, work life pressure, smooth balance work.....
# everything has been properly taken care by TCS.
# Summarize Text:
#  Work from home, safety precautions, updates, providing Mediclaim facilities, work life pressure, smooth balance work...... Likes As a TCSer, Yes, company has an ultimate support to me
# Likes There are no lay off in TCS, 100% job security
# They are paying internet cost also due to WFH in this panademic
#
# Summarize Text:
#  They are paying internet cost also due to WFH in this panademic. Likes There are no lay off in TCS, 100% job security
# Likes Supporting in every aspect
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I worked one and half year as a payroll, my manager keep telling that will convert, but it didn't happened and they removed all contract employees stating covid 19 impact, worst decision by TCS
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Apart from job security nothing is good for those working in analytics at NKP, Mumbai location
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes In lockdown, we have work from home.they have provided pc to those who were not having to do their work
# Even internet cost is given by the company during monthly salary.
# list index out of range
# Summarize Text:
#  Likes In lockdown, we have work from home.they have provided pc to those who were not having to do their work
# Likes Good at providing job security but failed in concerning employees issues and benefits
# Worst at hikes
# list index out of range
# Summarize Text:
#  Likes Good at providing job security but failed in concerning employees issues and benefits
# Likes Job is secured and no career growth here in TCS.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I was laid off though I was a contractor there
# So, I am not sure if their motive is to keep their permanent employees happy
# This is just my view
# I was told there are making me permanent employee but that never happened.
# Summarize Text:
#  This is just my view. So, I am not sure if their motive is to keep their permanent employees happy
# Likes Totally fracturing.
# I couldn't manage work life balance.
# working day and night without any compensation or hike.
#
# Summarize Text:
#  working day and night without any compensation or hike.. Likes Totally fracturing.
# Likes I am very happy to work with TCS
#  There  is a great opportunity to grown up my knowledge and my skills
#  There is a good team i got
#
# Summarize Text:
#   There is a good team i got.  There  is a great opportunity to grown up my knowledge and my skills
# Likes It has been good working in covid 19 bcz we are working from home and there was no cut off in salary as other companies did also the work system was delivered to us to Ur home address with safety
#
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Despite covid-19 pandemic still job is secure.So TCS is the best MNC company in the world.I am proude to be working with TCS
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Kindly help me with the proceduresto apply a transfer from mumbai location to my home town kerala location tcs either to trivandrum or kochin tcs due to covid pandemic
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Work life balance
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes I was so excited to work for TCS
#  But my process TL & Managers had made it worst for me
#  They made us work like slaves
#  And even if we achieved target,  the credits will be transferred to their favorite colleagues
#  There is so much of partiality &  negative  atmosphere inside the company
#  Higher authorities  doesn't have any manners or humanity
#  They just came to earn money & get their work done
#  They will try to put a good fake image before clients
#  They don't know that prior to clients,  empoloyes come
#  They will hire candidates as much as possible, but they don't know to manage them
# They are just mass recruiters
# It's just a show off company destroying the career of people
#  Only thing they know is to torture the employees
#  They just try to squeeze the energy of employees as much as possible
#  There is no ethics & no work culture
#  ...Read More
# Summarize Text:
#   There is so much of partiality &  negative  atmosphere inside the company.  They don't know that prior to clients,  empoloyes come
# Likes not supporting at all
# Have been applying leaves as they could not provide device to WFH
# list index out of range
# Summarize Text:
#  Likes not supporting at all
# Likes Job security is good and work culture and there is opportunity for learning and development.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Job security is the best part of TCS, even company is taking care of the associates who are on bench during this critical time, where people are loosing their jobs in other organisations.
# list index out of range
# list index out of range
# Summarize Text:
#
# Likes Best company to work with.
# Working with tcs was a superb experience.
# Job security, lenient policies
# list index out of range
# list index out of range
# Summarize Text:
# /home/siddharth/anaconda3/lib/python3.7/site-packages/nltk/cluster/util.py:133: RuntimeWarning: invalid value encountered in true_divide
#   return 1 - (numpy.dot(u, v) / (sqrt(numpy.dot(u, u)) * sqrt(numpy.dot(v, v))))
